# %% [markdown]
# # Population growth of India in last 140 Years
#    India is the 2 most populus country in th world.This is an excercs to show how the population of India has grown in last 140 years.

# %% [markdown]
# # Importing an image in Notebook

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
img=np.array(Image.open('C://Users/tomphi/Desktop/Github/Indian_Population_growth/India.png'))
fig=plt.figure(figsize=(10,10))
plt.imshow(img,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Importing excel data in Python

# %%
import pandas as pd 
#import matplotlib as plt 
df=pd.read_excel(open('C://Users/tomphi/Desktop/Github/Indian_Population_growth/Year_wise_Population_India.xlsx','rb'),sheetname='Sheet1')
#print(df.head())
print(df)
# Out:
#     Census year  Population Growth (%)
# 0          1871   238830958          –
# 1          1881   253896330        6.3
# 2          1891   287223431       13.1
# 3          1901   293550310        2.2
# 4          1911   315156396        7.4
# 5          1921   318942480        1.2
# 6          1931   352837778       10.6
# 7          1941   388997955       10.2
# 8          1951   361088000          –
# 9          1961   439235000       21.6
# 10         1971   548160000       24.8
# 11         1981   683329000       24.7
# 12         1991   846387888       23.9
# 13         2001  1028737436       21.5
# 14         2011  1210726932       17.7

# %%
df['Indian_Pop_Crores']= df['Population']/10000000
print(df)
# Out:
#     Census year  Population Growth (%)  Indian_Pop_Billions  Indian_Pop_Crores
# 0          1871   238830958          –            23.883096          23.883096
# 1          1881   253896330        6.3            25.389633          25.389633
# 2          1891   287223431       13.1            28.722343          28.722343
# 3          1901   293550310        2.2            29.355031          29.355031
# 4          1911   315156396        7.4            31.515640          31.515640
# 5          1921   318942480        1.2            31.894248          31.894248
# 6          1931   352837778       10.6            35.283778          35.283778
# 7          1941   388997955       10.2            38.899796          38.899796
# 8          1951   361088000          –            36.108800          36.108800
# 9          1961   439235000       21.6            43.923500          43.923500
# 10         1971   548160000       24.8            54.816000          54.816000
# ...

# %% [markdown]
# # Plotting a bar chart using matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.plot.bar('Census year', 'Indian_Pop_Crores')
